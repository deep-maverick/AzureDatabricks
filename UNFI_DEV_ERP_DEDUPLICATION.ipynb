# %% [markdown]
# ### Data Ingestion into Silver Stg schema for all ERP tables

# %%
import dlt
from pyspark.sql.functions import col, expr,unix_timestamp, lit, concat

# %%
# def create_temp_table(dict_): 
#     @dlt.create_table(name = dict_['temp_table_name'], temporary=True)
#     def streaming_table(dict_ = dict_):
#         df = (spark.readStream.format("delta").table(dict_['bronze_table_path']))
#         return df

# def load_data_in_silver(list_of_dict):
#     for dict_ in list_of_dict:
#         try:
#             spark.catalog.dropTempView(dict_['temp_table_name'])
#         except:
#             pass

#         create_temp_table(dict_)
        
#         dlt.create_streaming_live_table(\
#                 dict_['target_table_name'], 
#                 table_properties = {'delta.enableChangeDataFeed': 'true'})
#         dlt.apply_changes(
#         target = dict_['target_table_name'],
#         source = dict_['temp_table_name'],
#         keys = dict_['unique_key'],
#         sequence_by = dict_['sequence_by'],
#         stored_as_scd_type = "1"
#         )

# %%
catalog="dev"
ebx_mdm_schema = "raw_ebx_mdm"

raw_alb_erp = "raw_alb_bss"
raw_alb_relex_erp = "raw_alb_bss_relex"
raw_ubs_erp = "raw_ubs"
raw_ucs_erp = "raw_ucs_cid94d"
raw_ucs_relex_erp = "raw_ucs_relex"
raw_wbs_erp = "raw_wbs"
raw_wbs_relex_erp = "raw_wbs_relex"
ebx_schema_erp = "raw_ebx_mdm"

# %%
list_of_dict  = [

                ######################################   BELOW TABLES REQUIRED FOR BUSINESS PARTY MODEl  ##########################################
                
                {'temp_table_name': 'temp_ebx_bp_individ_address', 'bronze_table_path': 'dev.raw_ebx_mdm.ebx_bp_individ_address', 
                 'target_table_name': 'ebx_bp_individ_address', 'unique_key': ['id'], 'sequence_by': 'hvr_change_time'},
                
                {'temp_table_name': 'temp_ebx_bp_individ_phone_number', 'bronze_table_path': 'dev.raw_ebx_mdm.ebx_bp_individ_phone_number', 
                 'target_table_name': 'ebx_bp_individ_phone_number', 'unique_key': ['id'], 'sequence_by': 'hvr_change_time'},

                {'temp_table_name': 'temp_ebx_bp_individ_email_addr', 'bronze_table_path': 'dev.raw_ebx_mdm.ebx_bp_individ_email_addr', 
                 'target_table_name': 'ebx_bp_individ_email_addr', 'unique_key': ['id'], 'sequence_by': 'hvr_change_time'},

                {'temp_table_name': 'temp_ebx_bp_oranization_contact', 'bronze_table_path': 'dev.raw_ebx_mdm.ebx_bp_oranization_contact', 
                 'target_table_name': 'ebx_bp_oranization_contact', 'unique_key': ['id'], 'sequence_by': 'hvr_change_time'},
                 
                {'temp_table_name': 'temp_ebx_rf_country', 'bronze_table_path': 'dev.raw_ebx_mdm.ebx_rf_country', 
                 'target_table_name': 'ebx_rf_country', 'unique_key': ['iso3countrycd'], 'sequence_by': 'hvr_change_time'},
                 
                {'temp_table_name': 'temp_ebx_rf_address_type', 'bronze_table_path': 'dev.raw_ebx_mdm.ebx_rf_address_type', 
                 'target_table_name': 'ebx_rf_address_type', 'unique_key': ['addresstypecode'], 'sequence_by': 'hvr_change_time'},
                 
                {'temp_table_name': 'temp_ebx_br_phone_type', 'bronze_table_path': 'dev.raw_ebx_mdm.ebx_br_phone_type', 
                 'target_table_name': 'ebx_br_phone_type', 'unique_key': ['phonetype'], 'sequence_by': 'hvr_change_time'},

                {'temp_table_name': 'temp_ebx_br_email_type', 'bronze_table_path': 'dev.raw_ebx_mdm.ebx_br_email_type', 
                 'target_table_name': 'ebx_br_email_type', 'unique_key': ['emailtype'], 'sequence_by': 'hvr_change_time'}, 

                {'temp_table_name': 'temp_ebx_bp_individ_contact', 'bronze_table_path': 'dev.raw_ebx_mdm.ebx_bp_individ_contact', 
                 'target_table_name': 'ebx_bp_individ_contact', 'unique_key': ['id'], 'sequence_by': 'hvr_change_time'},
                
                {'temp_table_name': 'temp_ebx_br_contact_type', 'bronze_table_path': 'dev.raw_ebx_mdm.ebx_br_contact_type', 
                 'target_table_name': 'ebx_br_contact_type', 'unique_key': ['contacttype'], 'sequence_by': 'hvr_change_time'},
                
                
                ####################################    BELOW TaBLES REQUIRED FOR Distribution Center Model   ####################################
                
                {'temp_table_name': 'temp_ebx_ldc_dist_center', 'bronze_table_path': 'dev.raw_ebx_mdm.ebx_ldc_dist_center', 
                 'target_table_name': 'ebx_ldc_dist_center', 'unique_key': ['enterprisedistributioncenterid'], 'sequence_by': 'hvr_change_time'},
                
                {'temp_table_name': 'temp_ebx_lr_dist_ctr_class', 'bronze_table_path': 'dev.raw_ebx_mdm.ebx_lr_dist_ctr_class', 
                 'target_table_name': 'ebx_lr_dist_ctr_class', 'unique_key': ['distributioncenterclassification'], 'sequence_by': 'hvr_change_time'},
                
                {'temp_table_name': 'temp_ebx_lr_dist_ctr_type', 'bronze_table_path': 'dev.raw_ebx_mdm.ebx_lr_dist_ctr_type', 
                 'target_table_name': 'ebx_lr_dist_ctr_type', 'unique_key': ['distibutioncentertype'], 'sequence_by': 'hvr_change_time'},
                
                {'temp_table_name': 'temp_ebx_ldc_dist_center_distributioncentertype', 'bronze_table_path': 'dev.raw_ebx_mdm.ebx_ldc_dist_center_distributioncentertype', 
                 'target_table_name': 'ebx_ldc_dist_center_distributioncentertype', 'unique_key': ['enterprisedistributioncenterid'], 'sequence_by': 'hvr_change_time'},
                
                {'temp_table_name': 'temp_ebx_ldc_dist_ctr_bussys_rel', 'bronze_table_path': 'dev.raw_ebx_mdm.ebx_ldc_dist_ctr_bussys_rel', 
                 'target_table_name': 'ebx_ldc_dist_ctr_bussys_rel', 'unique_key': ['distributioncentername', 'businesssystemdistrbutioncenternumber', 'businesssystemcodeonly', 'businesssystem_' ],
                  'sequence_by': 'hvr_change_time'},
                
                {'temp_table_name': 'temp_ebx_ldc_location', 'bronze_table_path': 'dev.raw_ebx_mdm.ebx_ldc_location', 
                 'target_table_name': 'ebx_ldc_location', 'unique_key': ['locationid'], 'sequence_by': 'hvr_change_time'},
                
                {'temp_table_name': 'temp_ebx_ldc_dist_ctr_loc_rel', 'bronze_table_path': 'dev.raw_ebx_mdm.ebx_ldc_dist_ctr_loc_rel', 
                 'target_table_name': 'ebx_ldc_dist_ctr_loc_rel', 'unique_key': ['distributioncenter_'], 'sequence_by': 'hvr_change_time'},
                
                {'temp_table_name': 'temp_ebx_ldc_dist_ctr_clust_rel', 'bronze_table_path': 'dev.raw_ebx_mdm.ebx_ldc_dist_ctr_clust_rel', 
                 'target_table_name': 'ebx_ldc_dist_ctr_clust_rel', 'unique_key': ['distributioncenter_'], 'sequence_by': 'hvr_change_time'},
                
                {'temp_table_name': 'temp_ebx_ldc_dist_center_clust', 'bronze_table_path': 'dev.raw_ebx_mdm.ebx_ldc_dist_center_clust', 
                 'target_table_name': 'ebx_ldc_dist_center_clust', 'unique_key': ['enterprisedistributioncenterclusterid'], 'sequence_by': 'hvr_change_time'},
                
                {'temp_table_name': 'temp_ebx_ldc_dist_ctr_clstyp_rel', 'bronze_table_path': 'dev.raw_ebx_mdm.ebx_ldc_dist_ctr_clstyp_rel', 
                 'target_table_name': 'ebx_ldc_dist_ctr_clstyp_rel', 'unique_key': ['distributioncentercluster_'], 'sequence_by': 'hvr_change_time'},
                
                {'temp_table_name': 'temp_ebx_lr_dist_ctr_clus_type', 'bronze_table_path': 'dev.raw_ebx_mdm.ebx_lr_dist_ctr_clus_type', 
                 'target_table_name': 'ebx_lr_dist_ctr_clus_type', 'unique_key': ['distrubutioncenterclustertype',
                                                                                    'description',
                                                                                    't_last_user_id',
                                                                                    't_creator_id',
                                                                                    't_creation_date',
                                                                                    't_last_write',
                                                                                    'technical_rowinactivedate'
                                                                                    ], 'sequence_by': 'hvr_change_time'},

                        
            ################################   BELOW TABLES REQUIRED FOR CUSTOMER MODEL   ###############################
            
            {'temp_table_name': 'temp_ebx_cm_customer', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_cm_customer', 
            'target_table_name': 'ebx_cm_customer', 'unique_key': ['enterprisecustomerid'], 'sequence_by': 'hvr_change_time'
            },
            {'temp_table_name': 'temp_ebx_cr_statuscode', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_cr_statuscode', 
            'target_table_name': 'ebx_cr_statuscode', 'unique_key': ['enterprisestatuscode'], 'sequence_by': 'hvr_change_time'
            },
            {'temp_table_name': 'temp_ebx_cm_address', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_cm_address', 
            'target_table_name': 'ebx_cm_address', 'unique_key': ['enterpriseaddressid'], 'sequence_by': 'hvr_change_time'
            },
            {'temp_table_name': 'temp_ebx_cr_country', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_cr_country', 
            'target_table_name': 'ebx_cr_country', 'unique_key': ['countrycode'], 'sequence_by': 'hvr_change_time'
            },
            {'temp_table_name': 'temp_ebx_cm_customer_owner', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_cm_customer_owner', 
            'target_table_name': 'ebx_cm_customer_owner', 'unique_key': ['enterprisecustomerownerid'], 'sequence_by': 'hvr_change_time'
            },
            {'temp_table_name': 'temp_ebx_cr_channel', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_cr_channel', 
            'target_table_name': 'ebx_cr_channel', 'unique_key': ['enterprisechannelid'], 'sequence_by': 'hvr_change_time'
            },
            {'temp_table_name': 'temp_ebx_cr_cust_type', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_cr_cust_type', 
            'target_table_name': 'ebx_cr_cust_type', 'unique_key': ['enterprisecustomertypeid'], 'sequence_by': 'hvr_change_time'
            },
            {'temp_table_name': 'temp_ebx_cr_bus_system', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_cr_bus_system', 
            'target_table_name': 'ebx_cr_bus_system', 'unique_key': ['enterprisebusinesssystemid'], 'sequence_by': 'hvr_change_time'
            },
            {'temp_table_name': 'temp_ebx_cm_ord_acct', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_cm_ord_acct', 
            'target_table_name': 'ebx_cm_ord_acct', 'unique_key': ['enterprisecustomerorderingaccountid'], 'sequence_by': 'hvr_change_time'
            },
            {'temp_table_name': 'temp_ebx_cm_dc_ord_acct', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_cm_dc_ord_acct', 
            'target_table_name': 'ebx_cm_dc_ord_acct', 'unique_key': ['customerorderingaccount_'], 'sequence_by': 'hvr_change_time'
            },
            {'temp_table_name': 'temp_ebx_cm_billto', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_cm_billto', 
            'target_table_name': 'ebx_cm_billto', 'unique_key': ['enterprisecustomerbilltoid'], 'sequence_by': 'hvr_change_time'
            },
            {'temp_table_name': 'temp_ebx_cr_chain', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_cr_chain', 
            'target_table_name': 'ebx_cr_chain', 'unique_key': ['enterprisechainid'], 'sequence_by': 'hvr_change_time'
            },
            {'temp_table_name': 'temp_ebx_cr_banner', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_cr_banner', 
            'target_table_name': 'ebx_cr_banner', 'unique_key': ['enterprisebannerid'], 'sequence_by': 'hvr_change_time'
            },
            {'temp_table_name': 'temp_ebx_cm_ord_acct_cont_rel', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_cm_ord_acct_cont_rel', 
            'target_table_name': 'ebx_cm_ord_acct_cont_rel', 'unique_key': ['customerorderingaccountnumber'], 'sequence_by': 'hvr_change_time'
            },
            {'temp_table_name': 'temp_ebx_cr_contact_type', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_cr_contact_type', 
            'target_table_name': 'ebx_cr_contact_type', 'unique_key': ['enterprisecontacttypeid'], 'sequence_by': 'hvr_change_time'
            },
            {'temp_table_name': 'temp_ebx_cm_contact', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_cm_contact', 
            'target_table_name': 'ebx_cm_contact', 'unique_key': ['enterprisecontactid'], 'sequence_by': 'hvr_change_time'
            },
            {'temp_table_name': 'temp_ebx_cr_bus_system_banner', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_cr_bus_system_banner', 
            'target_table_name': 'ebx_cr_bus_system_banner', 'unique_key': ['businesssystemcode_'], 'sequence_by': 'hvr_change_time'
            },
            {'temp_table_name': 'temp_ebx_cr_bus_sys_cust_type', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_cr_bus_sys_cust_type', 
            'target_table_name': 'ebx_cr_bus_sys_cust_type', 'unique_key': ['businesssystemcustomertype'], 'sequence_by': 'hvr_change_time'
            },
            {'temp_table_name': 'temp_ebx_cr_bus_sys_chain', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_cr_bus_sys_chain', 
            'target_table_name': 'ebx_cr_bus_sys_chain', 'unique_key': ['businesssystemchain'], 'sequence_by': 'hvr_change_time'
            },
            
            {'temp_table_name': 'temp_ebx_cr_bus_system_channel', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_cr_bus_system_channel', 
            'target_table_name': 'ebx_cr_bus_system_channel', 'unique_key': ['businesssystemcode_', 'businesssystemchannel'], 'sequence_by': 'hvr_change_time'
            },

            #########################################    BELOW TABLES REQUIRED FOR VENDOR MODEL   ##############################################

            
            {'temp_table_name': 'temp_ebx_vm_vendor', 'bronze_table_path':  f'{catalog}.{ebx_mdm_schema}.ebx_vm_vendor', 
                 'target_table_name': 'ebx_vm_vendor', 'unique_key': ["enterprisevendorid"], 'sequence_by': 'hvr_change_time'
                },
                
            {'temp_table_name': 'temp_ebx_vm_vendor_bussystem_rel', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_vm_vendor_bussystem_rel',  'target_table_name': 'ebx_vm_vendor_bussystem_rel', 'unique_key': ['vendorcode','businesssystem_'], 'sequence_by': 'created_on'
                },

            {'temp_table_name': 'temp_ebx_vr_vend_rel_type', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_vr_vend_rel_type', 
                'target_table_name': 'ebx_vr_vend_rel_type', 'unique_key': ['relationshiptype'], 'sequence_by': 'created_on'
            },

            {'temp_table_name': 'temp_ebx_vr_vend_type', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_vr_vend_type', 
                'target_table_name': 'ebx_vr_vend_type', 'unique_key': ['vendortype'], 'sequence_by': 'created_on'
            },

                # {'temp_table_name': 'temp_ebx_vm_vendor_ind_rel', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_vm_vendor_ind_rel', 
                #  'target_table_name': 'ebx_vm_vendor_ind_rel', 'unique_key': ['vendor_','individual_'], 'sequence_by': 'created_on' 
                #  },

                # {'temp_table_name': 'temp_ebx_vm_vendor_vendor_rel', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_vm_vendor_vendor_rel', 
                #  'target_table_name': 'ebx_vm_vendor_vendor_rel', 'unique_key': ['vendor_','relatedvendor_'], 'sequence_by': 'created_on'
                # },
                 

                 #### !!!!!!!!!!!!!!! UPDATE UNQIUE PRIMARY KEY !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
                # {'temp_table_name': 'temp_ebx_vm_vendor_org_rel', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_vm_vendor_org_rel', 
                #  'target_table_name': 'ebx_vm_vendor_org_rel', 'unique_key': ['vendor_','organization_'], 'sequence_by': 'created_on'
                #  },
                
            {'temp_table_name': 'temp_ebx_vm_vendor_paymentdata_paymentmethods', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_vm_vendor_paymentdata_paymentmethods', 
                'target_table_name': 'ebx_vm_vendor_paymentdata_paymentmethods', 'unique_key': ['idx','enterprisevendorid'], 'sequence_by': 'created_on'
                },
            
            {'temp_table_name': 'temp_ebx_vm_vendor_paymentdata_paymentterms', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_vm_vendor_paymentdata_paymentterms', 
                'target_table_name': 'ebx_vm_vendor_paymentdata_paymentterms', 'unique_key': ['idx','enterprisevendorid'],
                'sequence_by': 'created_on'
                },
            
            {'temp_table_name': 'temp_ebx_vr_pay_method', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_vr_pay_method', 
                'target_table_name': 'ebx_vr_pay_method', 'unique_key': ['paymentmethod'], 'sequence_by': 'created_on'
                },
            
            {'temp_table_name': 'temp_ebx_vr_pay_terms', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_vr_pay_terms', 
                'target_table_name': 'ebx_vr_pay_terms', 'unique_key': ['paymentterms'], 'sequence_by': 'created_on'
                },
            
            {'temp_table_name': 'temp_ebx_bp_organization', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_bp_organization', 
                'target_table_name': 'ebx_bp_organization', 'unique_key': ['enterprisebusinesspartyid'], 'sequence_by': 'created_on'},

            {'temp_table_name': 'temp_ebx_rf_address', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_rf_address', 
                'target_table_name': 'ebx_rf_address', 'unique_key': ['enterpriseaddressid'], 'sequence_by': 'created_on'},
            
            {'temp_table_name': 'temp_ebx_bp_individual', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_bp_individual', 
                'target_table_name': 'ebx_bp_individual', 'unique_key': ['enterprisebusinesspartyid'], 'sequence_by': 'created_on'},
            
            ###############    PROFIT_CTR DEDUPLICATION TABLES   ################
            
            {'temp_table_name': 'temp_ebx_fm_gl_acct', 'bronze_table_path':  f'{catalog}.{ebx_mdm_schema}.ebx_fm_gl_acct', 
                 'target_table_name': 'ebx_fm_gl_acct', 'unique_key': ["enterprisegeneralledgeraccountid"], 'sequence_by': 'hvr_change_time'
                 },
                
            {'temp_table_name': 'temp_ebx_fm_profit_ctr', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_fm_profit_ctr',  'target_table_name': 'ebx_fm_profit_ctr', 'unique_key': ['profitcenterid'], 'sequence_by': 'hvr_change_time'
                },

            {'temp_table_name': 'temp_ebx_fm_cost_ctr', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_fm_cost_ctr', 
                'target_table_name': 'ebx_fm_cost_ctr', 'unique_key': ['enterpisecostcenterid'], 'sequence_by': 'hvr_change_time'
                },

            {'temp_table_name': 'temp_ebx_fr_gl_acct_group', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_fr_gl_acct_group', 
                'target_table_name': 'ebx_fr_gl_acct_group', 'unique_key': ['generalledgeraccountgroupcode'], 'sequence_by': 'hvr_change_time'
                },

            {'temp_table_name': 'temp_ebx_fr_gl_sort_key', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_fr_gl_sort_key', 
                'target_table_name': 'ebx_fr_gl_sort_key', 'unique_key': ['generalledgersortkey'], 'sequence_by': 'hvr_change_time'
                },

            {'temp_table_name': 'temp_ebx_fr_pl_acct_type', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_fr_pl_acct_type', 
                'target_table_name': 'ebx_fr_pl_acct_type', 'unique_key': ['placcounttypecode'], 'sequence_by': 'hvr_change_time'
                },

            {'temp_table_name': 'temp_ebx_fr_gl_cost_elmt_cat', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_fr_gl_cost_elmt_cat', 
                'target_table_name': 'ebx_fr_gl_cost_elmt_cat', 'unique_key': ['generalledgercostelementcategorycode'], 'sequence_by': 'hvr_change_time'
                },

            {'temp_table_name': 'temp_ebx_fr_tax_cat', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_fr_tax_cat', 
                'target_table_name': 'ebx_fr_tax_cat', 'unique_key': ['generalledgertaxcategorycode'], 'sequence_by': 'hvr_change_time'
                },

            {'temp_table_name': 'temp_ebx_rf_iso_currency', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_rf_iso_currency', 
                'target_table_name': 'ebx_rf_iso_currency', 'unique_key': ['isocurrencycode'], 'sequence_by': 'hvr_change_time'
                },

            {'temp_table_name': 'temp_ebx_rf_unfi_company', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_rf_unfi_company', 
                'target_table_name': 'ebx_rf_unfi_company', 'unique_key': ['unficompanycode'], 'sequence_by': 'hvr_change_time'
                },

            {'temp_table_name': 'temp_ebx_fr_gl_acct_type', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_fr_gl_acct_type', 
                'target_table_name': 'ebx_fr_gl_acct_type', 'unique_key': ['generalledgeraccounttypecode'], 'sequence_by': 'hvr_change_time'
                },

            {'temp_table_name': 'temp_ebx_fr_profit_center_seg', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_fr_profit_center_seg', 
                'target_table_name': 'ebx_fr_profit_center_seg', 'unique_key': ['segmentcode'], 'sequence_by': 'hvr_change_time'
                },

            {'temp_table_name': 'temp_ebx_fr_cost_center_cat', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_fr_cost_center_cat', 
                'target_table_name': 'ebx_fr_cost_center_cat', 'unique_key': ['costcentercategorycode'], 'sequence_by': 'hvr_change_time'
                },
            
            {'temp_table_name': 'temp_ebx_fm_profit_ctr_unficompanycode', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_fm_profit_ctr_unficompanycode', 
                'target_table_name': 'ebx_fm_profit_ctr_unficompanycode', 'unique_key': ['profitcenterid'], 'sequence_by': 'hvr_change_time'
            },

        #################   PURCHASE ORDER TABLES  ##############################

            {'temp_table_name': 'temp_ucs_sv_po_header', 'bronze_table_path': 'dev.raw_ucs_cid94d.sv_po_hdr', 
                 'target_table_name': 'ucs_sv_po_header', 'unique_key': ['sph_prft_cntr_nbr','sph_po_nbr'], 'sequence_by': 'hvr_change_time'},
                
            {'temp_table_name': 'temp_ucs_vendor', 'bronze_table_path': 'dev.raw_ucs_cid94d.vendor', 
                'target_table_name': 'ucs_vendor', 'unique_key': ['vnd_id','profit_cntr_nbr'], 'sequence_by': 'hvr_change_time'},          
        
            {'temp_table_name': 'temp_wbs_data_po_headers', 'bronze_table_path': 'dev.raw_wbs.po_headers', 
                'target_table_name': 'wbs_po_headers', 'unique_key': ['ponumber'], 'sequence_by': 'created_on'},

            {'temp_table_name': 'temp_wbs_data_open_po_header', 'bronze_table_path': 'dev.raw_wbs.open_po_header', 
                'target_table_name': 'wbs_open_po_header', 'unique_key': ['ponumber'], 'sequence_by': 'ArrivalDate'},

            {'temp_table_name': 'temp_wbs_data_cancel_po_header', 'bronze_table_path': 'dev.raw_wbs.cancel_po_header', 
                'target_table_name': 'wbs_cancel_po_header', 'unique_key': ['ponumber'], 'sequence_by': 'created_on'},

            {'temp_table_name': 'temp_ubs_data_open_po_header', 'bronze_table_path': 'dev.raw_ubs.open_po_header', 
                'target_table_name': 'ubs_open_po_header', 'unique_key': ['ordh_order'], 'sequence_by': 'created_on'},

            {'temp_table_name': 'temp_ubs_data_deletedpoheader', 'bronze_table_path': 'dev.raw_ubs.deletedpoheader', 
                'target_table_name': 'ubs_deletedpoheader', 'unique_key': ['dlpurh_num'], 'sequence_by': 'created_on'},
                
            {'temp_table_name': 'temp_ubs_data_received_po_header', 'bronze_table_path': 'dev.raw_ubs.received_po_header', 
                'target_table_name': 'ubs_received_po_header', 'unique_key': ['rpoh_num'], 'sequence_by': 'created_on'},
            
            {'temp_table_name': 'temp_ubs_data_vendor_master', 'bronze_table_path': 'dev.raw_ubs.vendor_master', 
                'target_table_name': 'ubs_vendor_master', 'unique_key': ['VEND_NUM'], 'sequence_by': 'created_on'},               

            {'temp_table_name': 'temp_ubs_data_product_master', 'bronze_table_path': 'dev.raw_ubs.product_master', 
                'target_table_name': 'ubs_product_master', 'unique_key': ['PROD_NUM'], 'sequence_by': 'created_on'},  
            
            {'temp_table_name': 'temp_wbs_data_product_master', 'bronze_table_path': 'dev.raw_wbs.product_master', 
                'target_table_name': 'wbs_product_master', 'unique_key': ['ProductNumber'], 'sequence_by': 'created_on'},  
            
            ## added on 2/11/23 ##

            {'temp_table_name': 'temp_ucs_sv_po_dtl', 'bronze_table_path': 'dev.raw_ucs_cid94d.sv_po_dtl', 
                'target_table_name': 'ucs_sv_po_dtl', 'unique_key': ['spd_prft_cntr_nbr','spd_po_nbr', 'spd_div_itm_id'], 'sequence_by': 'hvr_change_time'},
            
            {'temp_table_name': 'temp_ucs_post_buying_po_hdr', 'bronze_table_path': 'dev.raw_ucs_cid94d.post_buying_po_hdr', 
                'target_table_name': 'ucs_post_buying_po_hdr', 'unique_key': ['ph_pc_nbr','ph_po_nbr'], 'sequence_by': 'created_on'},
            
            {'temp_table_name': 'temp_ucs_post_buying_po_dtl', 'bronze_table_path': 'dev.raw_ucs_cid94d.post_buying_po_dtl', 
                'target_table_name': 'ucs_post_buying_po_dtl', 'unique_key': ['pd_pc_nbr','pd_po_nbr', 'pd_item_cd'], 'sequence_by': 'created_on'},
            
            {'temp_table_name': 'temp_ucs_sv_po_msg', 'bronze_table_path': 'dev.raw_ucs_cid94d.sv_po_msg', 
                'target_table_name': 'ucs_sv_po_msg', 'unique_key': ['spm_prft_cntr_nbr','spm_po_nbr'], 'sequence_by': 'hvr_change_time'},
            
            {'temp_table_name': 'temp_wbs_data_open_po_lines', 'bronze_table_path': 'dev.raw_wbs.open_po_lines', 
                'target_table_name': 'wbs_open_po_lines', 'unique_key': ['ponumber'], 'sequence_by': 'created_on'},
            
            {'temp_table_name': 'temp_wbs_data_po_lines', 'bronze_table_path': 'dev.raw_wbs.po_lines', 
                'target_table_name': 'wbs_po_lines', 'unique_key': ['ponumber'], 'sequence_by': 'created_on'},
            
            {'temp_table_name': 'temp_ubs_data_received_po_lines', 'bronze_table_path': 'dev.raw_ubs.received_po_lines', 
                'target_table_name': 'ubs_received_po_lines', 'unique_key': ['RPOL_NUM'], 'sequence_by': 'created_on'},

            {'temp_table_name': 'temp_ubs_data_open_po_lines', 'bronze_table_path': 'dev.raw_ubs.open_po_lines', 
                'target_table_name': 'ubs_open_po_lines', 'unique_key': ['ORDH_ORDER', 'ORDL_SEQ', 'PROD_NUM']	, 'sequence_by': 'ORDL_MATC'},
            
            {'temp_table_name': 'temp_alb_bss_inventory', 'bronze_table_path': 'dev.raw_alb_bss.inventory', 
                'target_table_name': 'alb_bss_inventory', 'unique_key': ['ID_Inventory'], 'sequence_by': 'hvr_change_time'},
            
            {'temp_table_name': 'temp_alb_bss_firstversionrecord', 'bronze_table_path': 'dev.raw_alb_bss.firstversionrecord', 
                'target_table_name': 'alb_bss_firstversionrecord', 'unique_key': ['idFirstVersionRecord'], 'sequence_by': 'hvr_change_time'},

            {'temp_table_name': 'temp_alb_bss_inventorytransfer', 'bronze_table_path': 'dev.raw_alb_bss.inventorytransfer',             
                'target_table_name': 'alb_bss_inventorytransfer', 'unique_key': ['ID_Inventory_To'], 'sequence_by': 'hvr_change_time'},
            
            {'temp_table_name': 'temp_alb_bss_supplier', 'bronze_table_path': 'dev.raw_alb_bss.supplier', 
                'target_table_name': 'alb_bss_supplier', 'unique_key': ['ID_Supplier'], 'sequence_by': 'hvr_change_time'},
            
            {'temp_table_name': 'temp_alb_bss_product', 'bronze_table_path': 'dev.raw_alb_bss.product', 
                'target_table_name': 'alb_bss_product', 'unique_key': ['ID_Product'], 'sequence_by': 'hvr_change_time'},
            
            {'temp_table_name': 'temp_alb_bss_inventory_arrivals', 'bronze_table_path': 'dev.raw_alb_bss.inventory_arrivals', 
                'target_table_name': 'alb_bss_inventory_arrivals', 'unique_key': ['ID_Inventory'], 'sequence_by': 'hvr_change_time'},

            {'temp_table_name': 'temp_alb_bss_relex_divisions', 'bronze_table_path': 'dev.raw_alb_bss_relex.divisions', 
                'target_table_name': 'alb_bss_relex_divisions', 'unique_key': ['ID_Divisions'], 'sequence_by': 'hvr_change_time'},

            {'temp_table_name': 'temp_alb_purchasing_buyer', 'bronze_table_path': 'dev.raw_alb_purchasing.buyer', 
                'target_table_name': 'alb_purchasing_buyer', 'unique_key': ['ID_Buyer'], 'sequence_by': 'hvr_change_time'},
    
            {'temp_table_name': 'temp_alb_purchasing_buyingorder', 'bronze_table_path': 'dev.raw_alb_purchasing.buyingorder', 
                'target_table_name': 'alb_purchasing_buyingorder', 'unique_key': ['ID_BuyingOrder'], 'sequence_by': 'hvr_change_time'},
        
            {'temp_table_name': 'temp_alb_purchasing_lineitem_wms', 'bronze_table_path': 'dev.raw_alb_purchasing.lineitem_wms', 
                'target_table_name': 'alb_purchasing_lineitem_wms', 'unique_key': ['ID_LineItem_WMS'] , 'sequence_by': 'hvr_change_time'},
            
            {'temp_table_name': 'temp_alb_purchasing_lineitems', 'bronze_table_path': 'dev.raw_alb_purchasing.lineitems', 
                'target_table_name': 'alb_purchasing_lineitems', 'unique_key': ['ID_LineItems'], 'sequence_by': 'hvr_change_time'},  

            ###################   MATERIAL INVENTORY & GOODS RECEIPT ADDITIONAL TABLES  ############################
            
            {'temp_table_name' : 'temp_product', 'bronze_table_path' : f'{catalog}.{raw_alb_erp}.product', 
                 'target_table_name' : 'alb_product', 'unique_key' : ['ID_Product'], 'sequence_by' : 'LastUpdated'},

            {'temp_table_name' : 'temp_liveinventory', 'bronze_table_path' : f'{catalog}.{raw_alb_erp}.liveinventory', 
                 'target_table_name' : 'alb_liveinventory', 'unique_key' : ["ID_LiveInventory"], 'sequence_by' : 'hvr_change_time'},
            
            {'temp_table_name' : 'temp_warehouselocation', 'bronze_table_path' : f'{catalog}.{raw_alb_erp}.warehouselocation', 
                 'target_table_name' : 'alb_warehouselocation', 'unique_key' : ['ID_WarehouseLocation'], 'sequence_by' : 'hvr_change_time'},

            #{'temp_table_name' : 'temp_Warehouse_Product', 'bronze_table_path' : f'{catalog}.{raw_ubs_erp}.Warehouse_Product', 
                 #'target_table_name' : 'Warehouse_Product', 'unique_key' : ["whse_whsloc","prod_num"], 'sequence_by' : 'created_on'},

            {'temp_table_name' : 'temp_ubs_warehouse', 'bronze_table_path' : f'{catalog}.{raw_ubs_erp}.warehouse', 
                 'target_table_name' : 'ubs_warehouse', 'unique_key' : ["WHSE_WHSLOC"], 'sequence_by' : 'created_on'},
            
            {'temp_table_name' : 'temp_warehouseinventoryactivity', 'bronze_table_path' : f'{catalog}.{raw_ubs_erp}.warehouseinventoryactivity', 
                 'target_table_name' : 'ubs_warehouseinventoryactivity', 'unique_key' : ["WMIN_IT_NUMBER", "WMIN_IN_WHITEM"], 'sequence_by' : 'created_on'},
            
            #{'temp_table_name' : 'temp_pc_itm', 'bronze_table_path' : f'{catalog}.{raw_ucs_erp}.pc_itm', 
            #'target_table_name' : 'pc_itm', 'unique_key' : ["pi_prod_key", "pi_pc_key"], 'sequence_by' : 'created_on'},

            {'temp_table_name' : 'temp_ucs_warehouse', 'bronze_table_path' : f'{catalog}.{raw_ucs_erp}.warehouse', 
                 'target_table_name' : 'ucs_warehouse', 'unique_key' : ["whse_pc_nbr"], 'sequence_by' : 'created_on'},
        
            {'temp_table_name' : 'temp_mpw_warehouse_product', 'bronze_table_path' : f'{catalog}.{raw_wbs_relex_erp}.mpw_warehouse_product', 
                'target_table_name' : 'wbs_mpw_warehouse_product', 'unique_key' : ["MPWWarehouseNumber", "ProductNumber"], 'sequence_by' : 'created_on'},
        
            {'temp_table_name' : 'temp_national_warehouses', 'bronze_table_path' : f'{catalog}.{raw_wbs_relex_erp}.national_warehouses', 
                'target_table_name' : 'wbs_national_warehouses', 'unique_key' :  ["DivisionCode","WarehouseNumber"], 'sequence_by' : 'created_on'},

        
            ################################# ITEM data model #####################
            
            {'temp_table_name' : 'temp_ebx_EBX_IM_Hierarchy_Def', 'bronze_table_path' : f'{catalog}.{ebx_schema_erp}.  EBX_IM_Hierarchy_Def', 
            'target_table_name' : 'EBX_IM_Hierarchy_Def', 'unique_key' : ["hierarchyname_"], 'sequence_by' : 'hvr_change_time'},
            
            {'temp_table_name' : 'temp_ebx_EBX_IM_Hierarchy_Def_Node', 'bronze_table_path' : f'{catalog}.{ebx_schema_erp}.EBX_IM_Hierarchy_Def_Node', 
            'target_table_name' : 'EBX_IM_Hierarchy_Def_Node', 'unique_key' : ["id"], 'sequence_by' : 'hvr_change_time'},
            
            {'temp_table_name' : 'temp_ebx_EBX_IM_Item', 'bronze_table_path' : f'{catalog}.{ebx_schema_erp}.EBX_IM_Item', 
             'target_table_name' : 'EBX_IM_Item', 'unique_key' : ["id"], 'sequence_by' : 'hvr_change_time'},
            
            {'temp_table_name' : 'temp_ebx_EBX_IM_Item_Hierarchy', 'bronze_table_path' : f'{catalog}.{ebx_schema_erp}.EBX_IM_Item_Hierarchy', 
            'target_table_name' : 'EBX_IM_Item_Hierarchy', 'unique_key' : ["item_", "itemname"], 'sequence_by' : 'hvr_change_time'},
            
            {'temp_table_name' : 'temp_ebx_EBX_IM_Item_To_Bus_Sys_Rel', 'bronze_table_path' : f'{catalog}.{ebx_schema_erp}.EBX_IM_Item_To_Bus_Sys_Rel', 
             'target_table_name' : 'EBX_IM_Item_To_Bus_Sys_Rel', 'unique_key' : ["item_","itemcode"], 'sequence_by' : 'hvr_change_time'},
            
            #{'temp_table_name' : 'temp_ebx_EBX_IM_Item_To_Item_Rel', 'bronze_table_path' : f'{catalog}.{ebx_schema_erp}.EBX_IM_Item_To_Item_Rel', 
            # 'target_table_name' : 'EBX_IM_Item_To_Item_Rel', 'unique_key' : ["item_"], 'sequence_by' : 'hvr_change_time'},
            
            {'temp_table_name' : 'temp_ebx_EBX_IM_Item_ToIndStand_Rel', 'bronze_table_path' : f'{catalog}.{ebx_schema_erp}.EBX_IM_Item_ToIndStand_Rel', 
             'target_table_name' : 'EBX_IM_Item_ToIndStand_Rel', 'unique_key' : ["value"], 'sequence_by' : 'hvr_change_time'},
            
            {'temp_table_name' : 'temp_ebx_EBX_IR_Hierarchy_Name', 'bronze_table_path' : f'{catalog}.{ebx_schema_erp}.EBX_IR_Hierarchy_Name', 
             'target_table_name' : 'EBX_IR_Hierarchy_Name', 'unique_key' : ["t_creation_date", "hierarchyname"], 'sequence_by' : 'hvr_change_time'},
            
            {'temp_table_name' : 'temp_ebx_EBX_IR_Item_Type', 'bronze_table_path' : f'{catalog}.{ebx_schema_erp}.EBX_IR_Item_Type', 
             'target_table_name' : 'EBX_IR_Item_Type', 'unique_key' : ["itemtype", "t_creation_date"], 'sequence_by' : 'hvr_change_time'},
            
            {'temp_table_name' : 'temp_ebx_ir_hierarchy_type', 'bronze_table_path' : f'{catalog}.{ebx_schema_erp}.ebx_ir_hierarchy_type', 
             'target_table_name' : 'ebx_ir_hierarchy_type', 'unique_key' : ["itemtype", "hierarchyname_", "domain", "hierarchytype"], 'sequence_by' : 'hvr_change_time'},
             
            {'temp_table_name' : 'temp_ebx_rf_business_system', 'bronze_table_path' : f'{catalog}.{ebx_schema_erp}.ebx_rf_business_system', 
             'target_table_name' : 'ebx_rf_business_system', 'unique_key' : ["enterprisebusinesssystemid"], 'sequence_by' : 'hvr_change_time'},
            
            # {'temp_table_name' : 'temp_ebx_bp_oranization_contact', 'bronze_table_path' : f'{catalog}.{ebx_schema_erp}.ebx_bp_oranization_contact', 
            #  'target_table_name' : 'ebx_bp_oranization_contact', 'unique_key' : ["id"], 'sequence_by' : 'hvr_change_time'}
            {'temp_table_name': 'temp_ebx_bp_org_address', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_bp_org_address', 
                 'target_table_name': 'ebx_bp_org_address', 'unique_key': ['id','address_'], 'sequence_by': 'created_on'},
                
              
            # {'temp_table_name': 'temp_ebx_bp_individ_address', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_bp_individ_address', 
            #     'target_table_name': 'ebx_bp_individ_address', 'unique_key': ['id','address_'], 'sequence_by': 'created_on'},
            

            {'temp_table_name': 'temp_ebx_bp_org_phone_number', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_bp_org_phone_number', 
                'target_table_name': 'ebx_bp_org_phone_number', 'unique_key': ['id','organization_'], 'sequence_by': 'created_on'},
            
            {'temp_table_name': 'temp_ebx_bp_org_email_addr', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_bp_org_email_addr', 
                'target_table_name': 'ebx_bp_org_email_addr', 'unique_key': ['id','organization_'], 'sequence_by': 'created_on'},
            
        ############# profit_center heriarchy  ############################

            {'temp_table_name': 'temp_ebx_fm_gl_acct_hier', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_fm_gl_acct_hier', 
                 'target_table_name': 'ebx_fm_gl_acct_hier', 'unique_key': ['hierarchynodekey'], 'sequence_by': 'hvr_change_time'},  
      
            {'temp_table_name': 'temp_ebx_fm_profit_ctr_hier', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_fm_profit_ctr_hier', 
                 'target_table_name': 'ebx_fm_profit_ctr_hier', 'unique_key': ['hierarchynodekey'], 'sequence_by': 'hvr_change_time'}, 

            {'temp_table_name': 'temp_ebx_fm_cost_ctr_hier', 'bronze_table_path': f'{catalog}.{ebx_mdm_schema}.ebx_fm_cost_ctr_hier', 
                 'target_table_name': 'ebx_fm_cost_ctr_hier', 'unique_key': ['hierarchynodekey'], 'sequence_by': 'hvr_change_time'} ,
            
        ####################Common refrence tables#####################################################
        
            {'temp_table_name': 'temp_ebx_rf_uom_conversion', 'bronze_table_path': 'dev.raw_ebx_mdm.ebx_rf_uom_conversion', 
            'target_table_name': 'ebx_rf_uom_conversion', 'unique_key': ['unitofmeasure_', 'uomnm', 'legacyunitofmeasure', 'businesssystem_'], 'sequence_by': 'hvr_change_time'},
            
            {'temp_table_name': 'temp_ebx_rf_unit_of_measure', 'bronze_table_path': 'dev.raw_ebx_mdm.ebx_rf_unit_of_measure', 
            'target_table_name': 'ebx_rf_unit_of_measure', 'unique_key': ['uomcd','uomnm'], 'sequence_by': 'hvr_change_time'},

        ####################Pharmacy xref tables#####################################################
        
            {'temp_table_name': 'temp_ebx_fx_pharmacy', 'bronze_table_path': 'dev.raw_ebx_mdm.ebx_fx_pharmacy', 
            'target_table_name': 'ebx_fx_pharmacy', 'unique_key': ['pharmacynumber'], 'sequence_by': 'hvr_change_time'},

        ####################Item heirarchy tables#####################################################
            {'temp_table_name' : 'temp_ebx_im_hierarchy_def_node_allowableparentitemtypes', 'bronze_table_path' : f'{catalog}.{ebx_schema_erp}.ebx_im_hierarchy_def_node_allowableparentitemtypes', 
            'target_table_name' : 'ebx_im_hierarchy_def_node_allowableparentitemtypes', 'unique_key' : ["id"], 'sequence_by' : 'hvr_change_time'},

        # #################### UOM CONVERSION  #####################################################    
        #     {'temp_table_name' : 'temp_ebx_rf_uom_conversion', 'bronze_table_path' : f'{catalog}.{ebx_schema_erp}.ebx_rf_uom_conversion', 
        #     'target_table_name' : 'ebx_rf_uom_conversion', 'unique_key' : ["legacyunitofmeasure","businesssystem_","unitofmeasure_","uomnm"], 'sequence_by' : 'hvr_change_time'}

        ####################AXSOne Xref tables#####################################################
        {'temp_table_name' : 'temp_ebx_fx_axs_act', 'bronze_table_path' : f'{catalog}.{ebx_schema_erp}.ebx_fx_axs_act', 
        'target_table_name' : 'ebx_fx_axs_act', 'unique_key' : ["id","accountcode"], 'sequence_by' : 'hvr_change_time'},

        {'temp_table_name' : 'temp_ebx_fx_axs_prd_brnd', 'bronze_table_path' : f'{catalog}.{ebx_schema_erp}.ebx_fx_axs_prd_brnd', 
        'target_table_name' : 'ebx_fx_axs_prd_brnd', 'unique_key' : ["id","axsonegeneralledgeraccountcode"], 'sequence_by' : 'hvr_change_time'},

        {'temp_table_name' : 'temp_ebx_fx_axs_pc_cc', 'bronze_table_path' : f'{catalog}.{ebx_schema_erp}.ebx_fx_axs_pc_cc', 
        'target_table_name' : 'ebx_fx_axs_pc_cc', 'unique_key' : ["id","accountctrcode"], 'sequence_by' : 'hvr_change_time'},
        
        ####################Retalix Canada tables#####################################################
        {'temp_table_name' : 'temp_ebx_fx_rtlx_can_act', 'bronze_table_path' : f'{catalog}.{ebx_schema_erp}.ebx_fx_rtlx_can_act', 
        'target_table_name' : 'ebx_fx_rtlx_can_act', 'unique_key' : ["id","accountcode"], 'sequence_by' : 'hvr_change_time'},

        {'temp_table_name' : 'temp_ebx_fx_rtlx_can_acct_maj_prdgrp_brnd', 'bronze_table_path' : f'{catalog}.{ebx_schema_erp}.ebx_fx_rtlx_can_acct_maj_prdgrp_brnd', 
        'target_table_name' : 'ebx_fx_rtlx_can_acct_maj_prdgrp_brnd', 'unique_key' : ["id","accountmajorcode"], 'sequence_by' : 'hvr_change_time'},

        {'temp_table_name' : 'temp_ebx_fx_rtlx_can_dept_cc', 'bronze_table_path' : f'{catalog}.{ebx_schema_erp}.ebx_fx_rtlx_can_dept_cc', 
        'target_table_name' : 'ebx_fx_rtlx_can_dept_cc', 'unique_key' : ["id","costcenter__costcenterid"], 'sequence_by' : 'hvr_change_time'},

        {'temp_table_name' : 'temp_ebx_fx_rtlx_can_dept_pc', 'bronze_table_path' : f'{catalog}.{ebx_schema_erp}.ebx_fx_rtlx_can_dept_pc', 
        'target_table_name' : 'ebx_fx_rtlx_can_dept_pc', 'unique_key' : ["id","profitcenter__profitcenterid"], 'sequence_by' : 'hvr_change_time'},


        ### NEW VENDOR TABLES ####
        {'temp_table_name' : 'temp_ebx_vm_vendor_overpaytrm', 'bronze_table_path' : f'{catalog}.{ebx_schema_erp}.ebx_vm_vendor_overpaytrm', 
        'target_table_name' : 'ebx_vm_vendor_overpaytrm', 'unique_key' : ["vendor_",	"distributioncenter_"], 'sequence_by' : 'hvr_change_time'},

        {'temp_table_name' : 'temp_ebx_vm_vendor_alt_name', 'bronze_table_path' : f'{catalog}.{ebx_schema_erp}.ebx_vm_vendor_alt_name', 
        'target_table_name' : 'ebx_vm_vendor_alt_name', 'unique_key' : ["vendor_","alternatenametype_"], 'sequence_by' : 'hvr_change_time'},

        {'temp_table_name' : 'temp_ebx_vr_vend_product_group', 'bronze_table_path' : f'{catalog}.{ebx_schema_erp}.ebx_vr_vend_product_group', 
        'target_table_name' : 'ebx_vr_vend_product_group', 'unique_key' : ["productgroup"], 'sequence_by' : 'hvr_change_time'},

        {'temp_table_name' : 'temp_ebx_vr_vend_alt_name_type', 'bronze_table_path' : f'{catalog}.{ebx_schema_erp}.ebx_vr_vend_alt_name_type', 
        'target_table_name' : 'ebx_vr_vend_alt_name_type', 'unique_key' : ["alternatenametype"], 'sequence_by' : 'hvr_change_time'}



]

# %%
for dict_ in list_of_dict:

    @dlt.table(name = dict_['temp_table_name'], temporary=True)
    def streaming_vendor(dict_ = dict_):
        df = (spark.readStream.format("delta").table(dict_['bronze_table_path']))
        return df

    dlt.create_streaming_live_table(\
            dict_['target_table_name'], 
            table_properties = {'delta.enableChangeDataFeed': 'true'})
    dlt.apply_changes(
    target = dict_['target_table_name'],
    source = dict_['temp_table_name'],
    keys = dict_['unique_key'],
    sequence_by = dict_['sequence_by'],
    stored_as_scd_type = "1"
    )
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
# ...
